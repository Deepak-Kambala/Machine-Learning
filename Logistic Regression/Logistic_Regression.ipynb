# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepak-Kambala/Machine-Learning/blob/main/Logistic_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Predicting if a person would buy life insurnace based on his age using logistic regression**

# %% [markdown]
# Above is a binary logistic regression problem as there are only two possible outcomes (i.e. if person buys insurance or he/she doesn't).

# %% [markdown]
# ![Screenshot 2025-09-07 102836.png](data:image/png;base64,...)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('insurance_data.csv')
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
plt.scatter(df.age, df.bought_insurance, marker = '+', color = 'red')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['age']], df['bought_insurance'], test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([1, 0, 0, 0, 1, 0])

# %%
model.score(X_test,y_test)
# Out:
# 0.8333333333333334

# %% [markdown]
# model.coef_ indicates value of m in y=m*x + b equation

# %%
model.coef_
# Out:
# array([[0.16198422]])

# %% [markdown]
# model.intercept_ indicates value of b in y=m*x + b equation

# %%
model.intercept_
# Out:
# array([-6.82205756])

# %% [markdown]
# Lets defined sigmoid function now and do the math with hand

# %%
import math
def sigmoid(x):
  return 1 / (1 + math.exp(-x))

# %%
def prediction_function(age):
    z = 0.162 * age - 6.82
    y = sigmoid(z)
    return y

# %%
age = 35
prediction_function(age)
# Out:
# 0.24048908305088887

# %% [markdown]
#  0.24 is less than 0.5 which means person with 35 age will not buy insurance

# %%
age = 43
prediction_function(age)
# Out:
# 0.5364353017406441

# %% [markdown]
# 0.536 is more than 0.5 which means person with 43 will buy the insurance
